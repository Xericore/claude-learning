# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
import os

load_dotenv()

client = Anthropic(base_url=os.getenv("ANTHROPIC_BASE_URL") or None)
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=0.5, stop_sequences=[]):

    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
    }

    if(system):
        params["system"] = system

    if(stop_sequences):
        params["stop_sequences"] = stop_sequences

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    answer = chat(messages, stop_sequences=["```"])
    answer = answer.strip()
    return json.loads(answer)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result."""
    prompt = f"""
Please solve the following task:
{test_case['task']}

* Respond only with python, json, or plain regex.
* Do not add any comments or commentary or explanations. 
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_response = chat(messages, stop_sequences=["```"])
    return json.loads(eval_response.strip())

# %%
import re
import ast

def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0
    
def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0
    
def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0

def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    elif format == "regex":
        return validate_regex(response)
    else:
        raise ValueError(f"Unknown format: {format}")

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result."""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    print(f"Model Score: {model_score}, Syntax Score: {syntax_score}")
    
    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case, 
        "score": score,
        "reasoning": reasoning
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case."""
    results = []
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average Score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)
    
results = run_eval(dataset)
# Out:
# Average Score: 6.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef parse_s3_bucket(s3_uri):\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if match:\n        return match.group(1)\n    return None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path'",
#       "format": "regex"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly solves the core task with a straightforward regex approach. However, it lacks robustness for production use. AWS S3 bucket names have specific naming constraints, and the function doesn't validate these. Additionally, no input sanitization or comprehensive edge case handling is present. For a basic parsing task it works well, but for a production AWS solution, more defensive programming would be expected."
#   },
#   {
#     "output": "\nimport json\n\nlambda_config = {\n    \"FunctionName\": \"my-lambda-function\",\n    \"Runtime\": \"python3.11\",\n    \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n    \"Timeout\": 60,\n    \"MemorySize\": 256\n}\n\nprint(json.dumps(lambda_config, indent=2))\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that includes function name, runtime, role ARN, timeout, and memory size",
#       "format": "json"
#     },
#     "score": 3.0,
#     "reasoning": "The solution successfully creates a valid JSON configuration object with all required fields and demonstrates correct AWS Lambda parameter naming conventions. However, it lacks production-readiness features such as parameterization, comprehensive field coverage, and validation. The hardcoded values make it unsuitable for real-world use cases where configurations need to be flexible across environments."
#   },
#   {
#     "output": "\nimport re\n\ndef validate_iam_role_arn(arn: str) -> bool:\n    \"\"\"\n    Validates an AWS IAM role ARN format.\n    \n    Valid IAM role ARN format:\n    arn:aws:iam::account-id:role/role-name\n    \"\"\"\n    pattern = r'^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$'\n    return bool(re.match(pattern, arn))\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        (\"arn:aws:iam::123456789012:role/MyRole\", True),\n        (\"arn:aws:iam::123456789012:role/service-role/MyRole\", True),\n        (\"arn:aws:iam::123456789012:role/my-role-name\", True),\n        (\"arn:aws:iam::123456789012:role/my_role_name\", True),\n        (\"arn:aws:iam::123456789012:role/my.role.name\", True),\n        (\"arn:aws:iam::123456789012:role/my+role\", True),\n        (\"arn:aws:iam::12345678901:role/MyRole\", False),  # Invalid account ID\n        (\"arn:aws:iam::1234567890123:role/MyRole\", False),  # Invalid account ID\n        (\"arn:aws:iam:us-east-1:123456789012:role/MyRole\", False),  # Region in IAM ARN\n        (\"arn:aws:iam::123456789012:user/MyUser\", False),  # Not a role\n        (\"arn:aws:ec2::123456789012:role/MyRole\", False),  # Wrong service\n        (\"invalid-arn\", False),\n        (\"\", False),\n    ]\n    \n    for arn, expected in test_cases:\n        result = validate_iam_role_arn(arn)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} {arn}: {result} (expected {expected})\")\n",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS IAM role ARN format and returns True if valid, False otherwise",
#       "format": "python"
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates solid understanding of IAM ARN structure and regex basics. However, there's a critical bug: the test case for 'arn:aws:iam::123456789012:role/service-role/MyRole' expects True but will fail because the pattern `[\\w+=,.@-]+` doesn't include forward slashes needed for path components. The regex should be `r'^arn:aws:iam::\\d{12}:role/[\\w+=,.@/-]+$'` to pass all stated tests. Additionally, production-grade validation should enforce AWS's documented constraints on role name/path lengths and support multiple AWS partitions."
#   }
# ]
